# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'geosheet.csv',
#  'read-var-files.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'test1.ipynb']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json("supermarkets.json")
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-semi-colons.txt",sep=';')
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-commas.txt")
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.loc["2":"3","Country":"Name"]
# Out:
#   Country         Name
# 2     USA  Super River
# 3     USA   Ben's Shop

# %%
list(df5.loc[:"country"])
# Out:
# ['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees']

# %%
df5.iloc[1:4,1:4]
# Out:
#           Address           City             State
# 1  735 Dolores St  San Francisco          CA 94119
# 2     332 Hill St  San Francisco  California 94114
# 3    3995 23rd St  San Francisco          CA 94114

# %%
df5.drop("City",1)
# Out:
#    ID          Address             State Country         Name  Employees
# 0   1     3666 21st St          CA 94114     USA      Madeira          8
# 1   2   735 Dolores St          CA 94119     USA  Bready Shop         15
# 2   3      332 Hill St  California 94114     USA  Super River         25
# 3   4     3995 23rd St          CA 94114     USA   Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA      Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df5.drop(df5.index[0:3],0)
# Out:
#    ID          Address           City       State Country        Name  \
# 3   4     3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop
# 4   5  1056 Sanchez St  San Francisco  California     USA     Sanchez
# 5   6  551 Alvarado St  San Francisco    CA 94114     USA  Richvalley
#
#    Employees
# 3         10
# 4         12
# 5         20

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
len(df5.index)
# Out:
# 6

# %%
df5["Profession"]=df5.shape[0]*["Py developer"]
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees    Profession
# 0          8  Py developer
# 1         15  Py developer
# 2         25  Py developer
# 3         10  Py developer
# 4         12  Py developer
# 5         20  Py developer

# %%
df5.shape
# Out:
# (6, 8)

# %%
df5["Country"]=df5["City"]+ "," +df5["Country"]
df5
# Out:
#    ID          Address           City             State  \
# 0   1     3666 21st St  San Francisco          CA 94114
# 1   2   735 Dolores St  San Francisco          CA 94119
# 2   3      332 Hill St  San Francisco  California 94114
# 3   4     3995 23rd St  San Francisco          CA 94114
# 4   5  1056 Sanchez St  San Francisco        California
# 5   6  551 Alvarado St  San Francisco          CA 94114
#
#                                          Country         Name  Employees  \
# 0  San Francisco,San Francisco,San Francisco,USA      Madeira          8
# 1  San Francisco,San Francisco,San Francisco,USA  Bready Shop         15
# 2  San Francisco,San Francisco,San Francisco,USA  Super River         25
# 3  San Francisco,San Francisco,San Francisco,USA   Ben's Shop         10
# 4  San Francisco,San Francisco,San Francisco,USA      Sanchez         12
# 5  San Francisco,San Francisco,San Francisco,USA   Richvalley         20
#
#      Profession
# 0  Py developer
# 1  Py developer
# ...

# %%
df5_t=df5.T
df5_t
# Out:
#                                                         0  \
# ID                                                      1
# Address                                      3666 21st St
# City                                        San Francisco
# State                                            CA 94114
# Country     San Francisco,San Francisco,San Francisco,USA
# Name                                              Madeira
# Employees                                               8
# Profession                                   Py developer
#
#                                                         1  \
# ID                                                      2
# Address                                    735 Dolores St
# City                                        San Francisco
# State                                            CA 94119
# Country     San Francisco,San Francisco,San Francisco,USA
# Name                                          Bready Shop
# ...

# %%
df5_t["6"]=["7","366 hill st","New City","New State","New Country","Aaron","10","AI Engineer"]
df5_t
# Out:
#                                                         0  \
# ID                                                      1
# Address                                      3666 21st St
# City                                        San Francisco
# State                                            CA 94114
# Country     San Francisco,San Francisco,San Francisco,USA
# Name                                              Madeira
# Employees                                               8
# Profession                                   Py developer
#
#                                                         1  \
# ID                                                      2
# Address                                    735 Dolores St
# City                                        San Francisco
# State                                            CA 94119
# Country     San Francisco,San Francisco,San Francisco,USA
# Name                                          Bready Shop
# ...

# %%
df5=df5_t.T
df5
# Out:
#   ID          Address           City             State  \
# 0  1     3666 21st St  San Francisco          CA 94114
# 1  2   735 Dolores St  San Francisco          CA 94119
# 2  3      332 Hill St  San Francisco  California 94114
# 3  4     3995 23rd St  San Francisco          CA 94114
# 4  5  1056 Sanchez St  San Francisco        California
# 5  6  551 Alvarado St  San Francisco          CA 94114
# 6  7      366 hill st       New City         New State
#
#                                          Country         Name Employees  \
# 0  San Francisco,San Francisco,San Francisco,USA      Madeira         8
# 1  San Francisco,San Francisco,San Francisco,USA  Bready Shop        15
# 2  San Francisco,San Francisco,San Francisco,USA  Super River        25
# 3  San Francisco,San Francisco,San Francisco,USA   Ben's Shop        10
# 4  San Francisco,San Francisco,San Francisco,USA      Sanchez        12
# 5  San Francisco,San Francisco,San Francisco,USA   Richvalley        20
# ...

# %%
df6=pandas.read_csv("geosheet.csv")
df6
# Out:
#    ID          Address         City_x     State_x Country_x       Name_x  \
# 0   2   735 Dolores St  San Francisco    CA 94119       USA  Bready Shop
# 1   4     3995 23rd St  San Francisco    CA 94114       USA   Ben's Shop
# 2   5  1056 Sanchez St  San Francisco  California       USA      Sanchez
# 3   6  551 Alvarado St  San Francisco    CA 94114       USA   Richvalley
#
#    Employees_x         City_y Country_y  Employees_y       Name_y     State_y  \
# 0           15  San Francisco       USA           15  Bready Shop    CA 94119
# 1           10  San Francisco       USA           10   Ben's Shop    CA 94114
# 2           12  San Francisco       USA           12      Sanchez  California
# 3           20  San Francisco       USA           20   Richvalley    CA 94114
#
#             Continent
# 0  USA, North America
# 1  USA, North America
# 2  USA, North America
# 3  USA, North America

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292200397371, -122.43169700840102, 0.0))

# %%
import pandas

# %%
df7=pandas.read_csv("supermarkets.csv")
df7
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7["Address"]=df7["Address"]+ ","+df7["City"]+","+df7["State"]+","+df7["Country"]
df7
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df7["Coordinates"]=df7["Address"].apply(nom.geocode)
df7
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df7["Coordinates"]=df7["Address"].apply(nom.geocode)
df7.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df7.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756648011392286, -122.42937496976432, 0.0))

# %%
df7.Coordinates[0].latitude
# Out:
# 37.756648011392286

# %%
df7["Latitude"]=df7["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df7["Longitude"]=df7["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df7
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
